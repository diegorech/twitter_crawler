# %%
# # Executa o script get_tweets.py para gerar um novo arquivo de tweets
# %run get_tweets.py

# %%
import json

with open('collected_tweets_2020-11-22-22-16-21.txt', 'r') as file:
    tweets = file.readlines()

# %%
# Fazendo o parse do tweet 2 vzs para virar type = dict e ficar no formato json
# e salvando isso em um arquivo .json
with open('tweet.json', 'w') as jsonfile:
    
    json.dump(
        json.loads( json.loads(tweets[0]) ), 
        jsonfile
    )

# %%
json.loads( json.loads(tweets[0]) )
# Out:
# {'created_at': 'Mon Nov 23 01:16:16 +0000 2020',
#  'id': 1330681540666404865,
#  'id_str': '1330681540666404865',
#  'text': 'RT @franjesus1: Sigue la censura @NinaSosVe @jomontenegro73 @Norys_Acosta_C @jagraterol2 @Jesus1405 @apurealvamar @Yosoydamian77 @daniel79l…',
#  'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#  'truncated': False,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'in_reply_to_screen_name': None,
#  'user': {'id': 1241882147285327873,
#   'id_str': '1241882147285327873',
#   'name': 'Madara -K-',
#   'screen_name': 'NavaVzla',
#   'location': 'Venezuela',
#   'url': None,
#   'description': 'Dile NO al Socialismo.\nDile NO al Globalismo.\nDile NO al Progresismo.\n.......Libertad, Orden y Justicia.',
#   'translator_type': 'none',
#   'protected': False,
#   'verified': False,
#   'followers_count': 1769,
#   'friends_count': 1374,
#   'listed_count': 2,
#   'favourites_count': 29815,
#   'statuses_count': 25825,
#   'created_at': 'Mon Mar 23 00:19:37 +0000 2020',
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': False,
#   'lang': None,
#   'contributors_enabled': False,
#   'is_translator': False,
#   'profile_background_color': 'F5F8FA',
#   'profile_background_image_url': '',
#   'profile_background_image_url_https': '',
#   'profile_background_tile': False,
#   'profile_link_color': '1DA1F2',
#   'profile_sidebar_border_color': 'C0DEED',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1325586797594873856/Rblof_8p_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1325586797594873856/Rblof_8p_normal.jpg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1241882147285327873/1593053624',
#   'default_profile': True,
#   'default_profile_image': False,
#   'following': None,
#   'follow_request_sent': None,
#   'notifications': None},
#  'geo': None,
#  'coordinates': None,
#  'place': None,
#  'contributors': None,
#  'retweeted_status': {'created_at': 'Mon Nov 23 00:57:46 +0000 2020',
#   'id': 1330676885676826629,
#   'id_str': '1330676885676826629',
#   'text': 'Sigue la censura @NinaSosVe @jomontenegro73 @Norys_Acosta_C @jagraterol2 @Jesus1405 @apurealvamar @Yosoydamian77… https://t.co/3uLbULrNs1',
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'truncated': True,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 231653274,
#    'id_str': '231653274',
#    'name': 'Francisco Hernández🇺🇸🇻🇪',
#    'screen_name': 'franjesus1',
#    'location': 'Venezuela apocalíptica. ',
#    'url': None,
#    'description': 'Venezolano en lucha permanente para vivir en democracia. Si no te gusta la crítica y la verdad no me sigas, se habla y se dice de todo no se salvará nadie.',
#    'translator_type': 'none',
#    'protected': False,
#    'verified': False,
#    'followers_count': 1987,
#    'friends_count': 2092,
#    'listed_count': 8,
#    'favourites_count': 51278,
#    'statuses_count': 47340,
#    'created_at': 'Wed Dec 29 03:22:27 +0000 2010',
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'profile_background_color': 'FA743E',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme10/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme10/bg.gif',
#    'profile_background_tile': True,
#    'profile_link_color': '9266CC',
#    'profile_sidebar_border_color': 'B7AE00',
#    'profile_sidebar_fill_color': '506C49',
#    'profile_text_color': '00AC57',
#    'profile_use_background_image': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1324176388585410561/GFtXZM2T_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1324176388585410561/GFtXZM2T_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/231653274/1598321368',
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'quoted_status_id': 1330671677211029506,
#   'quoted_status_id_str': '1330671677211029506',
#   'quoted_status': {'created_at': 'Mon Nov 23 00:37:05 +0000 2020',
#    'id': 1330671677211029506,
#    'id_str': '1330671677211029506',
#    'text': '.@SidneyPowell1 has been suspended from Twitter for 12 hours. She understands the WH press release &amp; agrees with it… https://t.co/XFugofaC4k',
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'truncated': True,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 240454812,
#     'id_str': '240454812',
#     'name': 'General Flynn',
#     'screen_name': 'GenFlynn',
#     'location': 'Parler, America',
#     'url': 'https://mikeflynndefensefund.org',
#     'description': 'Parler @GenFlynn #AmericanExceptionalism #DigitalSoldiers #BendedKnee ISAIAH 6:8 @TJHproject #TakeTheOath',
#     'translator_type': 'none',
#     'protected': False,
#     'verified': True,
#     'followers_count': 1021999,
#     'friends_count': 29608,
#     'listed_count': 3796,
#     'favourites_count': 274,
#     'statuses_count': 1789,
#     'created_at': 'Wed Jan 19 23:53:00 +0000 2011',
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/836614721726001152/tc1LJ2XF_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/836614721726001152/tc1LJ2XF_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/240454812/1603783248',
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': None,
#     'follow_request_sent': None,
#     'notifications': None},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'extended_tweet': {'full_text': '.@SidneyPowell1 has been suspended from Twitter for 12 hours. She understands the WH press release &amp; agrees with it. She is staying the course to prove the massive deliberate election fraud that robbed #WeThePeople of our votes for President Trump &amp; other Republican candidates.',
#     'display_text_range': [0, 286],
#     'entities': {'hashtags': [{'text': 'WeThePeople', 'indices': [206, 218]}],
#      'urls': [],
#      'user_mentions': [{'screen_name': 'SidneyPowell1',
#        'name': 'Sidney Powell 🇺🇸⭐⭐⭐',
#        'id': 586707638,
#        'id_str': '586707638',
#        'indices': [1, 15]}],
#      'symbols': []}},
#    'quote_count': 3318,
#    'reply_count': 3973,
#    'retweet_count': 18620,
#    'favorite_count': 45237,
#    'entities': {'hashtags': [],
#     'urls': [{'url': 'https://t.co/XFugofaC4k',
#       'expanded_url': 'https://twitter.com/i/web/status/1330671677211029506',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [121, 144]}],
#     'user_mentions': [{'screen_name': 'SidneyPowell1',
#       'name': 'Sidney Powell 🇺🇸⭐⭐⭐',
#       'id': 586707638,
#       'id_str': '586707638',
#       'indices': [1, 15]}],
#     'symbols': []},
#    'favorited': False,
#    'retweeted': False,
#    'filter_level': 'low',
#    'lang': 'en'},
#   'quoted_status_permalink': {'url': 'https://t.co/N2sYxh4KNH',
#    'expanded': 'https://twitter.com/GenFlynn/status/1330671677211029506',
#    'display': 'twitter.com/GenFlynn/statu…'},
#   'is_quote_status': True,
#   'extended_tweet': {'full_text': 'Sigue la censura @NinaSosVe @jomontenegro73 @Norys_Acosta_C @jagraterol2 @Jesus1405 @apurealvamar @Yosoydamian77 @daniel79lobo @amaromero79 @NavaVzla @Ma_Elisa_G @adsm9922 @GuilartFanny @franherr63 @joseromero8709 @mjdiazs64 @CoyoteCojoFLV @_TheRedShadow @BaldemiroL @LiliKinsman1',
#    'display_text_range': [0, 280],
#    'entities': {'hashtags': [],
#     'urls': [],
#     'user_mentions': [{'screen_name': 'NinaSosVe',
#       'name': 'Nina - My Parler is👉🏽 @NinaSosVe',
#       'id': 49014510,
#       'id_str': '49014510',
#       'indices': [17, 27]},
#      {'screen_name': 'jomontenegro73',
#       'name': 'Repúblico Johanna Montenegro',
#       'id': 155048058,
#       'id_str': '155048058',
#       'indices': [28, 43]},
#      {'screen_name': 'Norys_Acosta_C',
#       'name': 'Norys Acosta C - Parler: @NorysAcostaC',
#       'id': 312348029,
#       'id_str': '312348029',
#       'indices': [44, 59]},
#      {'screen_name': 'jagraterol2',
#       'name': 'JesusGraterol 131602 (Miembro de la CCL)',
#       'id': 1352744490,
#       'id_str': '1352744490',
#       'indices': [60, 72]},
#      {'screen_name': 'Jesus1405',
#       'name': 'Jesus Rodríguez',
#       'id': 127263549,
#       'id_str': '127263549',
#       'indices': [73, 83]},
#      {'screen_name': 'apurealvamar',
#       'name': 'Repúblico Acaymo',
#       'id': 148040456,
#       'id_str': '148040456',
#       'indices': [84, 97]},
#      {'screen_name': 'Yosoydamian77',
#       'name': 'Dámian Dukenfield 💡🔮',
#       'id': 99661080,
#       'id_str': '99661080',
#       'indices': [98, 112]},
#      {'screen_name': 'daniel79lobo',
#       'name': 'REPUBLICO Daniel González',
#       'id': 971414539,
#       'id_str': '971414539',
#       'indices': [113, 126]},
#      {'screen_name': 'amaromero79',
#       'name': 'maria romero',
#       'id': 1259679193,
#       'id_str': '1259679193',
#       'indices': [127, 139]},
#      {'screen_name': 'NavaVzla',
#       'name': 'Madara -K-',
#       'id': 1241882147285327873,
#       'id_str': '1241882147285327873',
#       'indices': [140, 149]},
#      {'screen_name': 'Ma_Elisa_G',
#       'name': '#VzlaEntrampadaEntreRojosYAzules🇻🇪🇻🇪',
#       'id': 86133400,
#       'id_str': '86133400',
#       'indices': [150, 161]},
#      {'screen_name': 'adsm9922',
#       'name': 'Marcos',
#       'id': 147944896,
#       'id_str': '147944896',
#       'indices': [162, 171]},
#      {'screen_name': 'GuilartFanny',
#       'name': 'Fanny Tamar',
#       'id': 859184422867939330,
#       'id_str': '859184422867939330',
#       'indices': [172, 185]},
#      {'screen_name': 'franherr63',
#       'name': 'Fco. Javier Herrera 🇻🇪🇪🇸',
#       'id': 1030600982441414656,
#       'id_str': '1030600982441414656',
#       'indices': [186, 197]},
#      {'screen_name': 'joseromero8709',
#       'name': 'REPÚBLICO José Romero 🇻🇪🇪🇸 Parler',
#       'id': 1688394074,
#       'id_str': '1688394074',
#       'indices': [198, 213]},
#      {'screen_name': 'mjdiazs64',
#       'name': 'Repúblico Mario José Díaz',
#       'id': 428699386,
#       'id_str': '428699386',
#       'indices': [214, 224]},
#      {'screen_name': 'CoyoteCojoFLV',
#       'name': 'COYOTECOJO REPÚBLICO',
#       'id': 91901742,
#       'id_str': '91901742',
#       'indices': [225, 239]},
#      {'screen_name': '_TheRedShadow',
#       'name': 'Red Shadow',
#       'id': 1269350360323371014,
#       'id_str': '1269350360323371014',
#       'indices': [240, 254]},
#      {'screen_name': 'BaldemiroL',
#       'name': 'Baldemiro Landino',
#       'id': 560621316,
#       'id_str': '560621316',
#       'indices': [255, 266]},
#      {'screen_name': 'LiliKinsman1',
#       'name': 'Lili',
#       'id': 1260416042351951873,
#       'id_str': '1260416042351951873',
#       'indices': [267, 280]}],
#     'symbols': []}},
#   'quote_count': 0,
#   'reply_count': 2,
#   'retweet_count': 4,
#   'favorite_count': 4,
#   'entities': {'hashtags': [],
#    'urls': [{'url': 'https://t.co/3uLbULrNs1',
#      'expanded_url': 'https://twitter.com/i/web/status/1330676885676826629',
#      'display_url': 'twitter.com/i/web/status/1…',
#      'indices': [114, 137]}],
#    'user_mentions': [{'screen_name': 'NinaSosVe',
#      'name': 'Nina - My Parler is👉🏽 @NinaSosVe',
#      'id': 49014510,
#      'id_str': '49014510',
#      'indices': [17, 27]},
#     {'screen_name': 'jomontenegro73',
#      'name': 'Repúblico Johanna Montenegro',
#      'id': 155048058,
#      'id_str': '155048058',
#      'indices': [28, 43]},
#     {'screen_name': 'Norys_Acosta_C',
#      'name': 'Norys Acosta C - Parler: @NorysAcostaC',
#      'id': 312348029,
#      'id_str': '312348029',
#      'indices': [44, 59]},
#     {'screen_name': 'jagraterol2',
#      'name': 'JesusGraterol 131602 (Miembro de la CCL)',
#      'id': 1352744490,
#      'id_str': '1352744490',
#      'indices': [60, 72]},
#     {'screen_name': 'Jesus1405',
#      'name': 'Jesus Rodríguez',
#      'id': 127263549,
#      'id_str': '127263549',
#      'indices': [73, 83]},
#     {'screen_name': 'apurealvamar',
#      'name': 'Repúblico Acaymo',
#      'id': 148040456,
#      'id_str': '148040456',
#      'indices': [84, 97]},
#     {'screen_name': 'Yosoydamian77',
#      'name': 'Dámian Dukenfield 💡🔮',
#      'id': 99661080,
#      'id_str': '99661080',
#      'indices': [98, 112]}],
#    'symbols': []},
#   'favorited': False,
#   'retweeted': False,
#   'filter_level': 'low',
#   'lang': 'es'},
#  'quoted_status_id': 1330671677211029506,
#  'quoted_status_id_str': '1330671677211029506',
#  'quoted_status': {'created_at': 'Mon Nov 23 00:37:05 +0000 2020',
#   'id': 1330671677211029506,
#   'id_str': '1330671677211029506',
#   'text': '.@SidneyPowell1 has been suspended from Twitter for 12 hours. She understands the WH press release &amp; agrees with it… https://t.co/XFugofaC4k',
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'truncated': True,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 240454812,
#    'id_str': '240454812',
#    'name': 'General Flynn',
#    'screen_name': 'GenFlynn',
#    'location': 'Parler, America',
#    'url': 'https://mikeflynndefensefund.org',
#    'description': 'Parler @GenFlynn #AmericanExceptionalism #DigitalSoldiers #BendedKnee ISAIAH 6:8 @TJHproject #TakeTheOath',
#    'translator_type': 'none',
#    'protected': False,
#    'verified': True,
#    'followers_count': 1021999,
#    'friends_count': 29608,
#    'listed_count': 3796,
#    'favourites_count': 274,
#    'statuses_count': 1789,
#    'created_at': 'Wed Jan 19 23:53:00 +0000 2011',
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/836614721726001152/tc1LJ2XF_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/836614721726001152/tc1LJ2XF_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/240454812/1603783248',
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'extended_tweet': {'full_text': '.@SidneyPowell1 has been suspended from Twitter for 12 hours. She understands the WH press release &amp; agrees with it. She is staying the course to prove the massive deliberate election fraud that robbed #WeThePeople of our votes for President Trump &amp; other Republican candidates.',
#    'display_text_range': [0, 286],
#    'entities': {'hashtags': [{'text': 'WeThePeople', 'indices': [206, 218]}],
#     'urls': [],
#     'user_mentions': [{'screen_name': 'SidneyPowell1',
#       'name': 'Sidney Powell 🇺🇸⭐⭐⭐',
#       'id': 586707638,
#       'id_str': '586707638',
#       'indices': [1, 15]}],
#     'symbols': []}},
#   'quote_count': 3318,
#   'reply_count': 3973,
#   'retweet_count': 18620,
#   'favorite_count': 45237,
#   'entities': {'hashtags': [],
#    'urls': [{'url': 'https://t.co/XFugofaC4k',
#      'expanded_url': 'https://twitter.com/i/web/status/1330671677211029506',
#      'display_url': 'twitter.com/i/web/status/1…',
#      'indices': [121, 144]}],
#    'user_mentions': [{'screen_name': 'SidneyPowell1',
#      'name': 'Sidney Powell 🇺🇸⭐⭐⭐',
#      'id': 586707638,
#      'id_str': '586707638',
#      'indices': [1, 15]}],
#    'symbols': []},
#   'favorited': False,
#   'retweeted': False,
#   'filter_level': 'low',
#   'lang': 'en'},
#  'quoted_status_permalink': {'url': 'https://t.co/N2sYxh4KNH',
#   'expanded': 'https://twitter.com/GenFlynn/status/1330671677211029506',
#   'display': 'twitter.com/GenFlynn/statu…'},
#  'is_quote_status': True,
#  'quote_count': 0,
#  'reply_count': 0,
#  'retweet_count': 0,
#  'favorite_count': 0,
#  'entities': {'hashtags': [],
#   'urls': [],
#   'user_mentions': [{'screen_name': 'franjesus1',
#     'name': 'Francisco Hernández🇺🇸🇻🇪',
#     'id': 231653274,
#     'id_str': '231653274',
#     'indices': [3, 14]},
#    {'screen_name': 'NinaSosVe',
#     'name': 'Nina - My Parler is👉🏽 @NinaSosVe',
#     'id': 49014510,
#     'id_str': '49014510',
#     'indices': [33, 43]},
#    {'screen_name': 'jomontenegro73',
#     'name': 'Repúblico Johanna Montenegro',
#     'id': 155048058,
#     'id_str': '155048058',
#     'indices': [44, 59]},
#    {'screen_name': 'Norys_Acosta_C',
#     'name': 'Norys Acosta C - Parler: @NorysAcostaC',
#     'id': 312348029,
#     'id_str': '312348029',
#     'indices': [60, 75]},
#    {'screen_name': 'jagraterol2',
#     'name': 'JesusGraterol 131602 (Miembro de la CCL)',
#     'id': 1352744490,
#     'id_str': '1352744490',
#     'indices': [76, 88]},
#    {'screen_name': 'Jesus1405',
#     'name': 'Jesus Rodríguez',
#     'id': 127263549,
#     'id_str': '127263549',
#     'indices': [89, 99]},
#    {'screen_name': 'apurealvamar',
#     'name': 'Repúblico Acaymo',
#     'id': 148040456,
#     'id_str': '148040456',
#     'indices': [100, 113]},
#    {'screen_name': 'Yosoydamian77',
#     'name': 'Dámian Dukenfield 💡🔮',
#     'id': 99661080,
#     'id_str': '99661080',
#     'indices': [114, 128]}],
#   'symbols': []},
#  'favorited': False,
#  'retweeted': False,
#  'filter_level': 'low',
#  'lang': 'es',
#  'timestamp_ms': '1606094176819'}
